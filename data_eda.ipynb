# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df= pd.read_csv('cleaned_dataset.csv')
df.head()
# Out:
#                    Job Title              Salary Estimate  \
# 0             Data Scientist   $53K-$91K (Glassdoor est.)
# 1  Healthcare Data Scientist  $63K-$112K (Glassdoor est.)
# 2             Data Scientist   $80K-$90K (Glassdoor est.)
# 3             Data Scientist   $56K-$97K (Glassdoor est.)
# 4             Data Scientist  $86K-$143K (Glassdoor est.)
#
#                                      Job Description  Rating  \
# 0  Data Scientist\r\nLocation: Albuquerque, NM\r\...     3.8
# 1  What You Will Do:\r\n\r\nI. General Summary\r\...     3.4
# 2  KnowBe4, Inc. is a high growth information sec...     4.8
# 3  *Organization and Job ID**\r\nJob ID: 310709\r...     3.8
# 4  Data Scientist\r\nAffinity Solutions / Marketi...     2.9
#
#                                    Company Name         Location  \
# 0                      Tecolote Research\r\n3.8  Albuquerque, NM
# 1  University of Maryland Medical System\r\n3.4    Linthicum, MD
# ...

# %%
df.describe()
# Out:
#            Rating      Founded      hourly  emp_provided     min_sal  \
# count  742.000000   742.000000  742.000000    742.000000  742.000000
# mean     3.618868  1837.154987    0.032345      0.022911   74.719677
# std      0.801210   497.183763    0.177034      0.149721   30.980593
# min     -1.000000    -1.000000    0.000000      0.000000   15.000000
# 25%      3.300000  1939.000000    0.000000      0.000000   52.000000
# 50%      3.700000  1988.000000    0.000000      0.000000   69.500000
# 75%      4.000000  2007.000000    0.000000      0.000000   91.000000
# max      5.000000  2019.000000    1.000000      1.000000  202.000000
#
#           max_sal     avg_sal  same_state  company_age      python  ...  \
# count  742.000000  742.000000  742.000000   742.000000  742.000000  ...
# mean   128.149596  101.427224    0.680593    46.591644    0.528302  ...
# std     45.220324   37.543705    0.466561    53.778815    0.499535  ...
# ...

# %%
df.columns
# Out:
# Index(['Job Title', 'Salary Estimate', 'Job Description', 'Rating',
#        'Company Name', 'Location', 'Headquarters', 'Size', 'Founded',
#        'Type of ownership', 'Industry', 'Sector', 'Revenue', 'Competitors',
#        'hourly', 'emp_provided', 'min_sal', 'max_sal', 'avg_sal', 'comp_name',
#        'state', 'hq_state', 'same_state', 'company_age', 'python', 'sql',
#        'spark', 'java', 'tableau', 'excel', 'hadoop', 'powerbi', 'gcp', 'aws',
#        'nosql', 'mongo', 'num_comp', 'job_simp', 'seniority', 'job_len'],
#       dtype='object')

# %%
df['Rating'].hist() #close to normal distribution

# %%
df['avg_sal'].hist() #normal distribution

# %%
df['company_age'].hist() #we have to normalize it

# %%
df.boxplot(column= ['avg_sal', 'company_age', 'Rating']) #some outliers for the avg salary and age

# %%
#Matrice de correlation
plt.figure(figsize=(25,25))
hm= sns.heatmap(df.corr(), annot= True, cmap= "RdYlGn")

# %%
df.columns
# Out:
# Index(['Job Title', 'Salary Estimate', 'Job Description', 'Rating',
#        'Company Name', 'Location', 'Headquarters', 'Size', 'Founded',
#        'Type of ownership', 'Industry', 'Sector', 'Revenue', 'Competitors',
#        'hourly', 'emp_provided', 'min_sal', 'max_sal', 'avg_sal', 'comp_name',
#        'state', 'hq_state', 'same_state', 'company_age', 'python', 'sql',
#        'spark', 'java', 'tableau', 'excel', 'hadoop', 'powerbi', 'gcp', 'aws',
#        'nosql', 'mongo', 'num_comp', 'job_simp', 'seniority', 'job_len'],
#       dtype='object')

# %%
#1st option
categ_cols= ['Industry', 'Sector', 'Revenue',
       'state', 'hq_state', 'python', 'sql',
       'spark', 'java', 'tableau', 'excel', 'hadoop', 'powerbi', 'gcp', 'aws',
       'nosql', 'mongo', 'num_comp', 'job_simp', 'seniority']
fig, axs = plt.subplots(nrows=5, ncols=4, figsize=(20, 40))
for col, ax in zip(categ_cols, axs.ravel()):
    chart=sns.countplot(x=col, data=df, ax=ax)
    chart.set_xticklabels(chart.get_xticklabels(), rotation=90)

# %%
#2nd option
plt.figure(figsize= (25,15))
df_cat= df[categ_cols]
for i in df_cat.columns:
    cat_num = df_cat[i].value_counts()
    print('Graph for %s: total = %d' % (i, len(cat_num)))
    chart=sns.barplot(x=cat_num.index, y= cat_num)
    chart.set_xticklabels(chart.get_xticklabels(), rotation=90)
    plt.show()
# Out:
# Graph for Industry: total = 60
# Graph for Sector: total = 25
# Graph for Revenue: total = 14
# Graph for state: total = 37
# Graph for hq_state: total = 47
# Graph for python: total = 2
# Graph for sql: total = 2
# Graph for spark: total = 2
# Graph for java: total = 2
# Graph for tableau: total = 2
# Graph for excel: total = 2
# Graph for hadoop: total = 2
# Graph for powerbi: total = 2
# Graph for gcp: total = 2
# Graph for aws: total = 2
# Graph for nosql: total = 2
# Graph for mongo: total = 2
# Graph for num_comp: total = 5
# Graph for job_simp: total = 7
# Graph for seniority: total = 3

# %%
pd.pivot_table(df, index = 'job_simp', values = 'avg_sal')
# Out:
#                    avg_sal
# job_simp
# data analyst     66.097087
# data engineer   105.728814
# data scientist  117.555556
# director        168.642857
# manager          84.181818
# ml              126.409091
# na               87.951087

# %%
pd.pivot_table(df, index = ['job_simp', 'seniority'], values = 'avg_sal')
# Out:
#                              avg_sal
# job_simp       seniority
# data analyst   junior      53.000000
#                na          61.324324
#                senior      80.148148
# data engineer  na          97.123457
#                senior     124.567568
# data scientist junior     106.000000
#                na         107.064516
#                senior     138.891304
# director       na         168.642857
# manager        na          84.181818
# ml             na         119.133333
#                senior     142.000000
# na             na          78.488189
#                senior     109.035088

# %%
pd.pivot_table(df, index = 'state', values = 'avg_sal').sort_values('avg_sal', ascending= False).head(15)
# Out:
#           avg_sal
# state
# CA     123.519737
# IL     116.575000
# DC     110.272727
# MA     107.300971
# NJ     104.588235
# MI     100.333333
# RI     100.000000
# NY      98.625000
# NC      98.571429
# MD      97.457143
# KY      97.333333
# VA      95.707317
# UT      94.000000
# PA      93.848485
# WA      93.047619

# %%
pd.pivot_table(df, index = ['state', 'job_simp'], values = 'avg_sal', aggfunc= 'count').sort_values('state', ascending= False).head(15)
# Out:
#                       avg_sal
# state job_simp
# WI    na                    4
#       data scientist        3
#       data analyst          3
# WA    na                    1
#       data scientist       17
#       data analyst          3
# VA    na                    5
#       ml                    2
#       data scientist       18
#       data engineer        10
#       data analyst          6
# UT    data engineer         3
#       data analyst          4
#       data scientist        3
# TX    na                    7

# %%
df_pivots = df[[ 'Rating', 'Industry', 'Sector', 'Revenue', 
       'hourly', 'emp_provided', 'num_comp', 'python', 'sql', 'avg_sal',
       'spark', 'java', 'tableau', 'excel', 'hadoop', 'powerbi', 'gcp', 'aws',
       'nosql', 'mongo', 'job_len']]

for i in df_pivots.columns:
    print(i)
    print('\n')
    print(pd.pivot_table(df_pivots, index=i, values= 'avg_sal').sort_values('avg_sal', ascending= False))
# Out:
# Rating
#
#
#            avg_sal
# Rating
# -1.0    136.181818
#  5.0    134.600000
#  2.5    120.000000
#  4.5    117.571429
#  4.1    116.368421
#  3.9    113.047619
#  2.6    109.250000
#  4.4    108.454545
#  4.0    107.234043
#  3.2    106.971429
#  3.7    105.688525
#  3.5    104.857143
#  4.7    103.806452
#  3.3    103.794872
#  4.3    102.562500
#  4.2    100.500000
#  2.2     98.000000
#  4.6     97.300000
#  3.8     97.278689
#  2.1     96.000000
#  3.4     93.522727
#  3.6     90.000000
#  1.9     88.000000
#  3.1     86.680000
#  3.0     85.529412
#  2.7     85.142857
#  2.8     84.142857
#  2.3     81.500000
#  2.9     81.277778
#  4.8     80.444444
#  2.4     59.714286
# Industry
#
#
#                                              avg_sal
# Industry
# Other Retail Stores                       164.000000
# Motion Picture Production & Distribution  146.000000
# Financial Analytics & Research            145.125000
# Health, Beauty, & Fitness                 140.000000
# ...

# %%
pd.pivot_table(df_pivots, index= 'Revenue', columns= 'python', values='avg_sal', aggfunc='count')
# Out:
# python                               0      1
# Revenue
# $1 to $2 billion (USD)            16.0   44.0
# $1 to $5 million (USD)             1.0    7.0
# $10 to $25 million (USD)          16.0   16.0
# $10+ billion (USD)                66.0   58.0
# $100 to $500 million (USD)        47.0   44.0
# $2 to $5 billion (USD)            17.0   22.0
# $25 to $50 million (USD)          24.0   16.0
# $5 to $10 billion (USD)            9.0   10.0
# $5 to $10 million (USD)            9.0    9.0
# $50 to $100 million (USD)         21.0   25.0
# $500 million to $1 billion (USD)  29.0   28.0
# -1                                 1.0    NaN
# Less than $1 million (USD)         1.0    3.0
# Unknown / Non-Applicable          93.0  110.0

# %%
pd.pivot_table(df_pivots, index= 'Revenue', columns= 'sql', values='avg_sal', aggfunc='count')
# Out:
# sql                                   0     1
# Revenue
# $1 to $2 billion (USD)             30.0  30.0
# $1 to $5 million (USD)              6.0   2.0
# $10 to $25 million (USD)           10.0  22.0
# $10+ billion (USD)                 77.0  47.0
# $100 to $500 million (USD)         37.0  54.0
# $2 to $5 billion (USD)             14.0  25.0
# $25 to $50 million (USD)           21.0  19.0
# $5 to $10 billion (USD)             1.0  18.0
# $5 to $10 million (USD)            11.0   7.0
# $50 to $100 million (USD)          21.0  25.0
# $500 million to $1 billion (USD)   29.0  28.0
# -1                                  1.0   NaN
# Less than $1 million (USD)          NaN   4.0
# Unknown / Non-Applicable          104.0  99.0

# %%
from wordcloud import WordCloud, ImageColorGenerator, STOPWORDS
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize

# %%
import texthero as hero
# Out:
# ✔ Download and installation successful
# You can now load the model via spacy.load('en_core_web_sm')

# %%
df['clean_description'] = hero.clean(df['Job Description'])
df['clean_description'].head()
# Out:
# 0    data scientist location albuquerque nm educati...
# 1    general summary healthcare data scientist posi...
# 2    knowbe4 inc high growth information security c...
# 3    organization job id job id directorate earth b...
# 4    data scientist affinity solutions marketing cl...
# Name: clean_description, dtype: object

# %%
words= " ".join(df['clean_description'])
wc= WordCloud(background_color= 'white', random_state=12, stopwords=STOPWORDS, max_words=2000, width=800, height=1500)
wc.generate(words)
plt.figure(figsize= (15,15))
plt.imshow(wc,interpolation='bilinear')
plt.axis('off')
plt.show()
